# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dlt
import math

# %%
df= pd.read_csv("C:/Users/91903/Flipkart_Mobiles.csv")
df
# Out:
#         Brand   Model            Color Memory Storage  Rating  Selling Price  \
# 0        OPPO     A53  Moonlight Black   4 GB   64 GB     4.5          11990
# 1        OPPO     A53       Mint Cream   4 GB   64 GB     4.5          11990
# 2        OPPO     A53  Moonlight Black   6 GB  128 GB     4.3          13990
# 3        OPPO     A53       Mint Cream   6 GB  128 GB     4.3          13990
# 4        OPPO     A53   Electric Black   4 GB   64 GB     4.5          11990
# ...       ...     ...              ...    ...     ...     ...            ...
# 3109  SAMSUNG  M52 5G    Blazing Black   6 GB  128 GB     4.3          25990
# 3110  SAMSUNG  M52 5G         Icy Blue   6 GB  128 GB     4.3          25489
# 3111  SAMSUNG  M52 5G         Icy Blue   8 GB  128 GB     4.3          27239
# 3112  SAMSUNG  M52 5G      Slate Black   8 GB  128 GB     4.2          22989
# 3113  SAMSUNG  M52 5G         Sky Blue   8 GB  128 GB     4.2          20350
#
#       Original Price
# 0              15990
# ...

# %%
df.describe()
# Out:
#             Rating  Selling Price  Original Price
# count  2970.000000    3114.000000     3114.000000
# mean      4.243098   26436.625562    28333.473025
# std       0.271991   30066.892622    31525.599889
# min       2.300000    1000.000000     1000.000000
# 25%       4.100000    9990.000000    10030.250000
# 50%       4.300000   15000.000000    16889.500000
# 75%       4.400000   28999.000000    31500.000000
# max       5.000000  179900.000000   189999.000000

# %%
df.shape
# Out:
# (3114, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3114 entries, 0 to 3113
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           3114 non-null   object
#  1   Model           3114 non-null   object
#  2   Color           3114 non-null   object
#  3   Memory          3071 non-null   object
#  4   Storage         3075 non-null   object
#  5   Rating          2970 non-null   float64
#  6   Selling Price   3114 non-null   int64
#  7   Original Price  3114 non-null   int64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 194.8+ KB

# %%
df["Selling Price"].dtype
# Out:
# dtype('int64')

# %%
df[].astype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12500\912043622.py in <module>
# ----> 1 df('Color').astype(int)
#
# TypeError: 'DataFrame' object is not callable

# %%
df = df.drop(columns=['Rating'])
df.head()
# Out:
#   Brand Model            Color Memory Storage  Selling Price  Original Price
# 0  OPPO   A53  Moonlight Black   4 GB   64 GB          11990           15990
# 1  OPPO   A53       Mint Cream   4 GB   64 GB          11990           15990
# 2  OPPO   A53  Moonlight Black   6 GB  128 GB          13990           17990
# 3  OPPO   A53       Mint Cream   6 GB  128 GB          13990           17990
# 4  OPPO   A53   Electric Black   4 GB   64 GB          11990           15990

# %%
df.isnull()
# Out:
#       Brand  Model  Color  Memory  Storage  Selling Price  Original Price
# 0     False  False  False   False    False          False           False
# 1     False  False  False   False    False          False           False
# 2     False  False  False   False    False          False           False
# 3     False  False  False   False    False          False           False
# 4     False  False  False   False    False          False           False
# ...     ...    ...    ...     ...      ...            ...             ...
# 3109  False  False  False   False    False          False           False
# 3110  False  False  False   False    False          False           False
# 3111  False  False  False   False    False          False           False
# 3112  False  False  False   False    False          False           False
# 3113  False  False  False   False    False          False           False
#
# [3114 rows x 7 columns]

# %%
df.sort_values("Brand")
# Out:
#      Brand                  Model            Color Memory Storage  \
# 455   ASUS        Zenfone Selfie              Pink   3 GB   32 GB
# 477   ASUS  ROG Phone 5 Ultimate             White  18 GB  512 GB
# 476   ASUS    ZenFone Max Pro M2              Blue   6 GB   64 GB
# 475   ASUS    Zenfone Max Pro M1             Black   3 GB   32 GB
# 474   ASUS            ZenFone 5Z     Midnight Blue   6 GB   64 GB
# ...    ...                    ...              ...    ...     ...
# 3018  vivo                  T1 5G  Starlight Black   6 GB  128 GB
# 3019  vivo                  T1 5G  Starlight Black   8 GB  128 GB
# 3020  vivo                  T1 5G  Rainbow Fantasy   4 GB  128 GB
# 2452  vivo                Y72 5G       Prism Magic   4 GB   64 GB
# 2442  vivo                   Y1s       Olive Black   6 GB   64 GB
#
#       Selling Price  Original Price
# 455           17999           17999
# 477           79999           85999
# 476           19999           19999
# ...

# %%
df['Selling Price'].fillna(df['Selling Price'].mean(),inplace=True)
df
# Out:
#         Brand   Model            Color Memory Storage  Selling Price  \
# 0        OPPO     A53  Moonlight Black   4 GB   64 GB          11990
# 1        OPPO     A53       Mint Cream   4 GB   64 GB          11990
# 2        OPPO     A53  Moonlight Black   6 GB  128 GB          13990
# 3        OPPO     A53       Mint Cream   6 GB  128 GB          13990
# 4        OPPO     A53   Electric Black   4 GB   64 GB          11990
# ...       ...     ...              ...    ...     ...            ...
# 3109  SAMSUNG  M52 5G    Blazing Black   6 GB  128 GB          25990
# 3110  SAMSUNG  M52 5G         Icy Blue   6 GB  128 GB          25489
# 3111  SAMSUNG  M52 5G         Icy Blue   8 GB  128 GB          27239
# 3112  SAMSUNG  M52 5G      Slate Black   8 GB  128 GB          22989
# 3113  SAMSUNG  M52 5G         Sky Blue   8 GB  128 GB          20350
#
#       Original Price
# 0              15990
# 1              15990
# 2              17990
# 3              17990
# 4              15990
# ...

# %%
df['Original Price'].fillna(df['Original Price'].median(),inplace=True)
df
# Out:
#         Brand   Model            Color Memory Storage  Selling Price  \
# 0        OPPO     A53  Moonlight Black   4 GB   64 GB          11990
# 1        OPPO     A53       Mint Cream   4 GB   64 GB          11990
# 2        OPPO     A53  Moonlight Black   6 GB  128 GB          13990
# 3        OPPO     A53       Mint Cream   6 GB  128 GB          13990
# 4        OPPO     A53   Electric Black   4 GB   64 GB          11990
# ...       ...     ...              ...    ...     ...            ...
# 3109  SAMSUNG  M52 5G    Blazing Black   6 GB  128 GB          25990
# 3110  SAMSUNG  M52 5G         Icy Blue   6 GB  128 GB          25489
# 3111  SAMSUNG  M52 5G         Icy Blue   8 GB  128 GB          27239
# 3112  SAMSUNG  M52 5G      Slate Black   8 GB  128 GB          22989
# 3113  SAMSUNG  M52 5G         Sky Blue   8 GB  128 GB          20350
#
#       Original Price
# 0              15990
# 1              15990
# 2              17990
# 3              17990
# 4              15990
# ...

# %%
df['Selling Price'].fillna(df['Selling Price'].max(),inplace=True)
df
# Out:
#         Brand   Model            Color Memory Storage  Selling Price  \
# 0        OPPO     A53  Moonlight Black   4 GB   64 GB          11990
# 1        OPPO     A53       Mint Cream   4 GB   64 GB          11990
# 2        OPPO     A53  Moonlight Black   6 GB  128 GB          13990
# 3        OPPO     A53       Mint Cream   6 GB  128 GB          13990
# 4        OPPO     A53   Electric Black   4 GB   64 GB          11990
# ...       ...     ...              ...    ...     ...            ...
# 3109  SAMSUNG  M52 5G    Blazing Black   6 GB  128 GB          25990
# 3110  SAMSUNG  M52 5G         Icy Blue   6 GB  128 GB          25489
# 3111  SAMSUNG  M52 5G         Icy Blue   8 GB  128 GB          27239
# 3112  SAMSUNG  M52 5G      Slate Black   8 GB  128 GB          22989
# 3113  SAMSUNG  M52 5G         Sky Blue   8 GB  128 GB          20350
#
#       Original Price
# 0              15990
# 1              15990
# 2              17990
# 3              17990
# 4              15990
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le
# Out:
# LabelEncoder()

# %%
df['Memory']=le.fit_transform(df['Memory'])
df['Memory']
# Out:
# 0       16
# 1       16
# 2       21
# 3       21
# 4       16
#         ..
# 3109    21
# 3110    21
# 3111    24
# 3112    24
# 3113    24
# Name: Memory, Length: 3114, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x=df.drop(columns=['Brand'])
y=df['Brand']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)
x,y
# Out:
# (      Model            Color  Memory Storage  Selling Price  Original Price
#  0       128  Moonlight Black      16   64 GB          11990           15990
#  1       128       Mint Cream      16   64 GB          11990           15990
#  2       128  Moonlight Black      21  128 GB          13990           17990
#  3       128       Mint Cream      21  128 GB          13990           17990
#  4       128   Electric Black      16   64 GB          11990           15990
#  ...     ...              ...     ...     ...            ...             ...
#  3109    528    Blazing Black      21  128 GB          25990           25990
#  3110    528         Icy Blue      21  128 GB          25489           28449
#  3111    528         Icy Blue      24  128 GB          27239           31489
#  3112    528      Slate Black      24  128 GB          22989           22989
#  3113    528         Sky Blue      24  128 GB          20350           22595
#
#  [3114 rows x 6 columns],
#  0          OPPO
# ...

# %%
plt.scatter(df['Brand'],df['Original Price'])
